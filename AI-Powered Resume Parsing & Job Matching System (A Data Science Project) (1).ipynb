# %%
import zipfile
import os

zip_path = r"C:\Users\Ganesh\Downloads\Dataset.zip"
extract_path = r"C:\Users\Ganesh\Downloads\Dataset_Extracted"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
root_folder = r"C:\Users\Ganesh\Downloads\Dataset_Extracted"

print("Subfolders:")
for f in os.listdir(root_folder):
    full_path = os.path.join(root_folder, f)
    if os.path.isdir(full_path):
        print(f"'{f}'")
# Out:
# Subfolders:
# 'Dataset'

# %%
all_pdfs = glob.glob(os.path.join(root_folder, "**", "*.pdf"), recursive=True)
print(f"Found {len(all_pdfs)} PDFs:")
for path in all_pdfs:
    print(path)
# Out:
# Found 200 PDFs:
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1061.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1070.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1080.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1161.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1164.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1191.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1212.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1228.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1236.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1320.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1446.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1487.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1499.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1547.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1627.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1677.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1701.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1781.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1789.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1791.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1796.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2098.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2139.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2144.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2235.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2250.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2256.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2287.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2430.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2546.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2603.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2607.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2652.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2669.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2720.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2775.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2808.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2836.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2838.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2872.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3014.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3017.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3019.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3045.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3127.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3142.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3169.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3226.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3315.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3363.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3416.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3445.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3464.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3539.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3557.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3570.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3620.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3627.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3717.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3761.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3771.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3821.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3830.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3863.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3899.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3912.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3922.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4021.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4024.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4194.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4256.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4277.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4307.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4331.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4336.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4439.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4444.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4460.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4482.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4507.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4523.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4552.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4573.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4602.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4627.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4686.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4742.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4760.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4919.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4999.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5007.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5121.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5125.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5230.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5339.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5390.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5451.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5507.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5591.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5638.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5649.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5661.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5725.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5756.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5767.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5786.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5804.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C5951.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6059.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6129.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6140.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6239.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6277.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6302.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6315.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6357.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6384.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6507.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6583.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6592.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6631.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6658.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6746.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6768.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6776.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6942.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6951.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C6979.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7032.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7093.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7094.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7128.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7226.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7228.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7230.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7231.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7242.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7254.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7315.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7318.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7482.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7492.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7497.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7527.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7535.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7543.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7550.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7554.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7733.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7775.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7784.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7831.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7842.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7869.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7934.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7979.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C7996.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8035.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8063.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8203.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8239.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8398.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8420.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8518.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8564.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8631.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8676.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8692.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8730.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8760.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8782.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8810.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8849.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8886.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C8928.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9104.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9117.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9142.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9146.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9165.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9200.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9207.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9228.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9262.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9282.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9342.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9369.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9533.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9534.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9567.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9590.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9628.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9677.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9742.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9777.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9779.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9884.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9897.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9919.pdf
# C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C9945.pdf

# %%
# Run this in a Jupyter Notebook cell
# !pip install langchain langchain-community langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\ganesh\anaconda3\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-community in c:\users\ganesh\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-openai in c:\users\ganesh\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.68)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-openai) (1.93.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.4.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: sniffio in c:\users\ganesh\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.2.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (3.5.0)
# Requirement already satisfied: tqdm>4 in c:\users\ganesh\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.64.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ganesh\anaconda3\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.9.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ganesh\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\ganesh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ganesh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ganesh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: colorama in c:\users\ganesh\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.86.0->langchain-openai) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)

# %%
from pydantic import BaseModel, Field
from typing import List, Optional
# Education Section
class Education(BaseModel):
    university_name: str = Field(..., description='Name of the university')
    degree: str = Field(..., description='Degree Obtained')
    gpa: Optional[float] = Field(None, ge=0, le=10.0, description='GPA')

# %%
# Experience Section
class Experience(BaseModel):
    company_name: Optional[str] = Field(..., description='Name of the company')
    n_years: Optional[int] = Field(..., ge=0, description='Years of experience in the company')
    project_name: Optional[str] = Field(..., description='Main project name')
    project_description: Optional[str] = Field(..., description='Project description & role')
    tech_stack: Optional[str] = Field(..., description='Technologies/tools used')

# %%
# Resume Schema
class Resume(BaseModel):
    name: str = Field(..., description='Candidate full name')
    age: Optional[int] = Field(None, ge=0, description='Age of the candidate')
    email: str = Field(..., description='Email address')
    phone_number: str = Field(..., description='Phone number')
    experience: Optional[List[Experience]] = Field(..., description='Work experience')
    education: Optional[List[Education]] = Field(..., description='Education background')
    languages: Optional[str] = Field(..., description='Languages known')

# %%
from langchain.prompts import PromptTemplate

resume_template = """
You are an AI assistant tasked with extracting structured information from a technical resume.

Only Extract the information that's present in the Resume class.

Resume Context:
{resume_text}
"""

prompt_template = PromptTemplate(
    template=resume_template,
    input_variables=['resume_text']
)

# %%
import os

# Set your API key securely (DO NOT share it publicly)
os.environ["OPENAI_API_KEY"] = "-your api secret key-"

# Now initialize your model
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model='gpt-4o-mini',
    model_provider='openai'
).with_structured_output(Resume, method="function_calling")

# %%
# !pip install pypdf

from langchain_community.document_loaders import PyPDFLoader

pdf_path = r"C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1161.pdf"

loader = PyPDFLoader(pdf_path)
docs = loader.load()
resume_text = "\n".join([doc.page_content for doc in docs])

print(resume_text[:500])  # Optional: print first 500 characters for inspection
# Out:
# Requirement already satisfied: pypdf in c:\users\ganesh\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pypdf) (4.12.2)
# Candidate Resume (ID: C1161)
# Name: Richard Molina
# Email: richardmolina72@gmail.com
# Phone: +1-908-7110
# Education
# Bachelor of Engineering in Information Technology (2014-2018)
# Concentrated on database management, networking, and cybersecurity.
# Master of Business Administration (2017-2019)
# Focused on Business Strategy, Financial Analysis, and Operations Management.
# Bachelor of Science in Computer Science (2015-2019)
# Specialized in Software Development and AI, with projects in deep learning and clou

# %%
pip install langchain langchain-community langchain-groq pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\ganesh\anaconda3\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-community in c:\users\ganesh\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-groq in c:\users\ganesh\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: pypdf in c:\users\ganesh\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.68)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: groq<1,>=0.29.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-groq) (0.29.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pypdf) (4.12.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (0.28.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.9.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: httpcore==1.* in c:\users\ganesh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ganesh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ganesh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import zipfile
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_groq import ChatGroq
from langchain_community.document_loaders import PyPDFLoader

# ----------- Step 1: Extract ZIP File -----------
zip_path = r"C:\Users\Ganesh\Downloads\Dataset.zip"
extract_path = r"C:\Users\Ganesh\Downloads\Dataset_Extracted"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

root_folder = extract_path
print("Subfolders:")
for f in os.listdir(root_folder):
    full_path = os.path.join(root_folder, f)
    if os.path.isdir(full_path):
        print(f"'{f}'")

# ----------- Step 2: Enhanced Resume Schema -----------
class Education(BaseModel):
    university_name: str
    degree: str
    gpa: Optional[float] = Field(None, ge=0, le=10.0)

class Experience(BaseModel):
    company_name: Optional[str]
    n_years: Optional[int] = Field(None, ge=0)
    project_name: Optional[str]
    project_description: Optional[str]
    tech_stack: Optional[str]

class Resume(BaseModel):
    name: str
    age: Optional[int] = Field(None, ge=0)
    email: str
    phone_number: str
    experience: Optional[List[Experience]]
    education: Optional[List[Education]]
    languages: Optional[str]
    skills: Optional[str]
    address: Optional[str]
    linkedin: Optional[str]

# ----------- Step 3: Groq API Key -----------
os.environ["GROQ_API_KEY"] = "your api secret key"

# ----------- Step 4: Initialize Model via Groq -----------
llm = ChatGroq(
    temperature=0,
    model_name="llama3-70b-8192"

)

parser = PydanticOutputParser(pydantic_object=Resume)

prompt = PromptTemplate(
    template="""
You are an AI assistant extracting structured data from a resume.

Only extract information that is present in the resume and relevant to the following schema:
{format_instructions}

Resume Content:
{resume_text}
""",
    input_variables=["resume_text"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# ----------- Step 5: Load All PDFs and Parse -----------

pdf_paths = glob.glob(os.path.join(root_folder, "**", "*.pdf"), recursive=True)
print(f"Found {len(pdf_paths)} PDFs.")

for pdf_path in pdf_paths:
    print(f"\nProcessing: {os.path.basename(pdf_path)}")
    try:
        loader = PyPDFLoader(pdf_path)
        docs = loader.load()
        resume_text = "\n".join([doc.page_content for doc in docs])

        formatted_prompt = prompt.format_prompt(resume_text=resume_text)
        result = llm.invoke(formatted_prompt.to_string())
        parsed = parser.invoke(result)

        print(parsed.json(indent=2))
    except Exception as e:
        print(f"Failed to process {pdf_path}: {e}")
# Out:
# Subfolders:
# 'Dataset'
# Found 200 PDFs.
#
# Processing: C1061.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1061.pdf: Failed to parse Resume from completion {"name": "Alyssa Chavez", "email": "alyssachavez88@gmail.com", "phone_number": "+1-465-3587", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1070.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1070.pdf: Failed to parse Resume from completion {"name": "Scott Saunders", "email": "scottsaunders13@gmail.com", "phone_number": "+1-367-5130", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Python, TensorFlow, PyTorch, PostgreSQL, Docker, Kubernetes", "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Master of Business Administration", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1080.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1080.pdf: Failed to parse Resume from completion {"name": "Pamela Kerr", "email": "pamelakerr20@gmail.com", "phone_number": "+1-453-5337", "experience": [{"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Python, TensorFlow, PyTorch, PostgreSQL, Docker, Kubernetes"}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null, "age": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1161.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1161.pdf: Failed to parse Resume from completion {"name": "Richard Molina", "age": null, "email": "richardmolina72@gmail.com", "phone_number": "+1-908-7110", "experience": [{"company_name": "DEF Ltd.", "n_years": null, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}, {"company_name": "XYZ Corp", "n_years": null, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Master of Business Administration", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1164.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1164.pdf: Failed to parse Resume from completion {"name": "Deborah Foster", "email": "deborahfoster16@gmail.com", "phone_number": "+1-767-2089", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": 4}, {"company_name": "ABC Inc.", "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1191.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1191.pdf: Failed to parse Resume from completion {"name": "Tracey Jones", "email": "traceyjones36@gmail.com", "phone_number": "+1-641-5966", "experience": [{"company_name": "ABC Inc.", "n_years": null, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%", "tech_stack": null}, {"company_name": "DEF Ltd.", "n_years": null, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%", "tech_stack": null}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1212.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1212.pdf: Failed to parse Resume from completion {"name": "Robert Flores", "age": null, "email": "robertflores62@gmail.com", "phone_number": "+1-985-1665", "experience": [{"company_name": "XYZ Corp", "n_years": null, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null}, {"company_name": "ABC Inc.", "n_years": null, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1228.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1228.pdf: Failed to parse Resume from completion {"name": "Jeffrey Gordon", "age": null, "email": "jeffreygordon62@gmail.com", "phone_number": "+1-518-2240", "experience": [{"company_name": "XYZ Corp", "n_years": null, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null}, {"company_name": "DEF Ltd.", "n_years": null, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1236.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1236.pdf: Failed to parse Resume from completion {"name": "Amanda Schneider", "email": "amandaschneider31@gmail.com", "phone_number": "+1-414-9371", "experience": [{"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1320.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1320.pdf: Failed to parse Resume from completion {"name": "Ryan Flowers", "email": "ryanflowers36@gmail.com", "phone_number": "+1-466-7250", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps"}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1446.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1446.pdf: Failed to parse Resume from completion {"name": "Daniel Bailey", "email": "danielbailey75@gmail.com", "phone_number": "+1-969-9430", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps", "n_years": null}], "education": [{"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1487.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1487.pdf: Failed to parse Resume from completion {"name": "Gary Davis", "email": "garydavis62@gmail.com", "phone_number": "+1-936-5656", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": 4}, {"company_name": "ABC Inc.", "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1499.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1499.pdf: Failed to parse Resume from completion {"name": "Brian Hurley", "age": null, "email": "brianhurley66@gmail.com", "phone_number": "+1-933-4959", "experience": [{"company_name": "XYZ Corp", "n_years": null, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null}, {"company_name": "DEF Ltd.", "n_years": null, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1547.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1547.pdf: Failed to parse Resume from completion {"name": "Tracy Sanchez", "email": "tracysanchez80@gmail.com", "phone_number": "+1-774-6561", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1627.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1627.pdf: Failed to parse Resume from completion {"name": "Dennis Schwartz", "email": "dennisschwartz64@gmail.com", "phone_number": "+1-708-7305", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%", "tech_stack": null}, {"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%", "tech_stack": null}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1677.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1677.pdf: Failed to parse Resume from completion {"name": "Shelley Bartlett", "email": "shelleybartlett86@gmail.com", "phone_number": "+1-797-5775", "experience": [{"company_name": "ABC Inc.", "n_years": null, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1701.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1701.pdf: Failed to parse Resume from completion {"name": "Sandra Stone", "email": "sandrastone76@gmail.com", "phone_number": "+1-818-5512", "experience": [{"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps"}, {"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1781.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1781.pdf: Failed to parse Resume from completion {"name": "Mary Tyler", "email": "marytyler35@gmail.com", "phone_number": "+1-643-3679", "experience": [{"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1789.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1789.pdf: Failed to parse Resume from completion {"name": "Heather Clay", "email": "heatherclay62@gmail.com", "phone_number": "+1-523-8524", "experience": [{"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1791.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1791.pdf: Failed to parse Resume from completion {"name": "April Duarte", "email": "aprilduarte34@gmail.com", "phone_number": "+1-918-8393", "experience": [{"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C1796.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1796.pdf: Failed to parse Resume from completion {"name": "Joseph Sexton", "email": "josephsexton49@gmail.com", "phone_number": "+1-495-2811", "experience": [{"company_name": "ABC Inc.", "n_years": null, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps"}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}, {"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2098.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2098.pdf: Failed to parse Resume from completion {"name": "Michael Juarez", "email": "michaeljuarez73@gmail.com", "phone_number": "+1-542-9519", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": null}, {"company_name": "ABC Inc.", "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null, "n_years": null}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Master of Business Administration", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2139.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2139.pdf: Failed to parse Resume from completion {"name": "Zachary Gregory", "age": null, "email": "zacharygregory28@gmail.com", "phone_number": "+1-986-3762", "experience": [{"company_name": "ABC Inc.", "n_years": null, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%", "tech_stack": null}, {"company_name": "XYZ Corp", "n_years": null, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2144.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2144.pdf: Failed to parse Resume from completion {"name": "Stacey Hunter", "email": "staceyhunter24@gmail.com", "phone_number": "+1-850-5303", "experience": [{"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2235.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2235.pdf: Failed to parse Resume from completion {"name": "Stacie Griffith", "email": "staciegriffith91@gmail.com", "phone_number": "+1-622-3437", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Python, TensorFlow, PyTorch, PostgreSQL, Docker, Kubernetes", "n_years": 4}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Master of Business Administration", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2250.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2250.pdf: Failed to parse Resume from completion {"name": "Mary Miller", "email": "marymiller98@gmail.com", "phone_number": "+1-440-8514", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2256.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2256.pdf: Failed to parse Resume from completion {"name": "Leonard Adams", "email": "leonardadams83@gmail.com", "phone_number": "+1-412-3126", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": null}, {"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": null}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null, "age": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2287.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2287.pdf: Failed to parse Resume from completion {"name": "Brian May", "email": "brianmay26@gmail.com", "phone_number": "+1-532-6295", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps"}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null, "age": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2430.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2430.pdf: Failed to parse Resume from completion {"name": "Victoria Burton", "email": "victoriaburton73@gmail.com", "phone_number": "+1-393-5083", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2546.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2546.pdf: Failed to parse Resume from completion {"name": "Kristy Henderson", "email": "kristyhenderson98@gmail.com", "phone_number": "+1-692-3834", "experience": [{"company_name": "ABC Inc.", "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null, "n_years": 4}, {"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2603.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2603.pdf: Failed to parse Resume from completion {"name": "Charles Garcia", "email": "charlesgarcia79@gmail.com", "phone_number": "+1-516-6814", "experience": [{"company_name": "ABC Inc.", "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%", "tech_stack": null, "n_years": 4}, {"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2607.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2607.pdf: Failed to parse Resume from completion {"name": "Sarah Mccullough", "email": "sarahmccullough41@gmail.com", "phone_number": "+1-776-4613", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%", "tech_stack": null}, {"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints", "tech_stack": null}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C2652.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C2652.pdf: Failed to parse Resume from completion {"name": "James Smith", "email": "jamessmith59@gmail.com", "phone_number": "+1-999-9289", "experience": [{"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "C++, OpenCV, Deep Learning, PyTorch, NVIDIA CUDA"}], "education": [{"university_name": null, "degree": "Master of Business Administration", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null, "age": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
# ...
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C3899.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3899.pdf: Failed to parse Resume from completion {"name": "Oscar Perry", "email": "oscarperry25@gmail.com", "phone_number": "+1-901-6901", "experience": [{"company_name": "XYZ Corp", "n_years": 4, "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps"}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C3912.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3912.pdf: Failed to parse Resume from completion {"name": "Kimberly Scott", "email": "kimberlyscott70@gmail.com", "phone_number": "+1-676-8273", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Java, Spring Boot, MySQL, Kafka, Azure DevOps", "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Master of Business Administration", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C3922.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C3922.pdf: Failed to parse Resume from completion {"name": "Alyssa Hansen", "email": "alyssahansen36@gmail.com", "phone_number": "+1-598-4564", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "C++, OpenCV, Deep Learning, PyTorch, NVIDIA CUDA", "n_years": 4}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Python & Machine Learning", "address": null, "linkedin": null, "age": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4021.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4021.pdf: Failed to parse Resume from completion {"name": "Ryan Smith", "email": "ryansmith96@gmail.com", "phone_number": "+1-410-6094", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": "Python, TensorFlow, PyTorch, PostgreSQL, Docker, Kubernetes", "n_years": 4}], "education": [{"university_name": null, "degree": "Master of Business Administration", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4024.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4024.pdf: Failed to parse Resume from completion {"name": "Andrew Watson", "email": "andrewwatson32@gmail.com", "phone_number": "+1-513-7715", "experience": [{"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Diploma in Software Engineering", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 1 validation error for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4194.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4194.pdf: Failed to parse Resume from completion {"name": "Tracy Gould", "email": "tracygould38@gmail.com", "phone_number": "+1-618-9417", "experience": [{"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}, {"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Ph.D. in Artificial Intelligence", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cybersecurity", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4256.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4256.pdf: Failed to parse Resume from completion {"name": "Lauren Le", "email": "laurenle40@gmail.com", "phone_number": "+1-972-2700", "experience": [{"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": 4}, {"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": 4}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4277.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4277.pdf: Failed to parse Resume from completion {"name": "Melissa Campos", "email": "melissacampos94@gmail.com", "phone_number": "+1-673-2408", "experience": [{"company_name": "DEF Ltd.", "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null, "n_years": null}, {"company_name": "XYZ Corp", "project_name": null, "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.", "tech_stack": null, "n_years": null}], "education": [{"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}, {"university_name": null, "degree": "Master of Science in Data Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}], "languages": null, "skills": "Cybersecurity - Skilled in penetration testing, risk assessment, and securing enterprise networks against cyber threats.", "address": null, "linkedin": null}. Got: 3 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.2.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4307.pdf
# Failed to process C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C4307.pdf: Failed to parse Resume from completion {"name": "Misty Anthony", "email": "mistyanthony22@gmail.com", "phone_number": "+1-781-7195", "experience": [{"company_name": "DEF Ltd.", "n_years": 4, "project_name": null, "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.", "tech_stack": null}, {"company_name": "ABC Inc.", "n_years": 4, "project_name": null, "project_description": "Built predictive models that enhanced decision-making processes, reducing operational costs by 25%.", "tech_stack": null}], "education": [{"university_name": null, "degree": "Bachelor of Science in Computer Science", "gpa": null}, {"university_name": null, "degree": "Bachelor of Engineering in Information Technology", "gpa": null}], "languages": null, "skills": "Cloud Computing - Expert in AWS, Azure, and GCP; implemented scalable cloud architectures for enterprise applications.", "address": null, "linkedin": null}. Got: 2 validation errors for Resume
# education.0.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# education.1.university_name
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Processing: C4331.pdf

# %%
job_description = """
We are hiring a Data Analyst with 2+ years experience in SQL, Python, and Power BI.
Familiarity with data cleaning, exploratory analysis, and dashboarding is a must.
Experience in financial or e-commerce domains preferred.
"""

# %%
pip install langchain langchain-community langchain-groq pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\ganesh\anaconda3\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-community in c:\users\ganesh\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-groq in c:\users\ganesh\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: pypdf in c:\users\ganesh\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.68)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: groq<1,>=0.29.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-groq) (0.29.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pypdf) (4.12.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (21.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ganesh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (3.5.0)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ganesh\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ganesh\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ganesh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.9.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: httpcore==1.* in c:\users\ganesh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ganesh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ganesh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ganesh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["GROQ_API_KEY"] = "your api secret key"

# %%
from pydantic import BaseModel, Field
from typing import List, Optional

class Education(BaseModel):
    university_name: str
    degree: str
    gpa: Optional[float] = Field(None, ge=0, le=10.0)

class Experience(BaseModel):
    company_name: Optional[str]
    n_years: Optional[int]
    project_name: Optional[str]
    project_description: Optional[str]
    tech_stack: Optional[str]

class Resume(BaseModel):
    name: str
    age: Optional[int]
    email: str
    phone_number: str
    experience: Optional[List[Experience]]
    education: Optional[List[Education]]
    languages: Optional[str]
    skills: Optional[str]
    address: Optional[str]
    linkedin: Optional[str]

# %%
import os
import json
from typing import List, Optional
from pydantic import BaseModel, Field
from dotenv import load_dotenv

# Setup GROQ API Key (either via .env or hardcoded for testing only)
os.environ["GROQ_API_KEY"] = "your api secret key"

# Define schema
class Education(BaseModel):
    university_name: Optional[str] = None
    degree: Optional[str] = None
    gpa: Optional[float] = Field(None, ge=0, le=10.0)

class Experience(BaseModel):
    company_name: Optional[str]
    n_years: Optional[int]
    project_name: Optional[str]
    project_description: Optional[str]
    tech_stack: Optional[str]

class Resume(BaseModel):
    name: str
    age: Optional[int]
    email: str
    phone_number: str
    experience: Optional[List[Experience]]
    education: Optional[List[Education]]
    languages: Optional[str]
    skills: Optional[str]
    address: Optional[str]
    linkedin: Optional[str]

# LLM setup
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_community.document_loaders import PyPDFLoader

llm = ChatGroq(
    model_name="llama3-70b-8192",
    temperature=0
)

# Output parser
parser = PydanticOutputParser(pydantic_object=Resume)

# Prompt template
prompt = PromptTemplate(
    template="""
You are an AI assistant that extracts structured data from resumes.

Only return fields based on the schema:
{format_instructions}

⚠️ Ensure all important fields like university name and degree are not null. If not available, return "Unknown".

Respond ONLY with a valid JSON object without explanation, markdown, or commentary.

Resume Text:
{resume_text}
""",
    input_variables=["resume_text"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# Load PDF
pdf_path = r"C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1161.pdf"
loader = PyPDFLoader(pdf_path)
docs = loader.load()
resume_text = "\n".join([doc.page_content for doc in docs])

# Format and invoke prompt
formatted_prompt = prompt.format_prompt(resume_text=resume_text)
response = llm.invoke(formatted_prompt.to_string())

# Extract clean JSON from response
response_text = response.content if hasattr(response, 'content') else str(response)

# Remove code fences and extract valid JSON
def extract_json_from_response(text: str) -> str:
    if "```" in text:
        parts = text.split("```")
        for part in parts:
            try:
                return json.loads(part.strip())
            except json.JSONDecodeError:
                continue
        raise ValueError("No valid JSON block found in code fences.")
    else:
        return json.loads(text.strip())

try:
    raw_json = extract_json_from_response(response_text)
except Exception as e:
    print("❌ Could not parse JSON from LLM response. Raw response:\n", response_text)
    raise e

# Parse into Pydantic model
parsed_resume = Resume(**raw_json)

# Pretty print output
print(parsed_resume.model_dump_json(indent=2))
# Out:
# {
#   "name": "Richard Molina",
#   "age": null,
#   "email": "richardmolina72@gmail.com",
#   "phone_number": "+1-908-7110",
#   "experience": [
#     {
#       "company_name": "DEF Ltd.",
#       "n_years": 4,
#       "project_name": "Unknown",
#       "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.",
#       "tech_stack": "Unknown"
#     },
#     {
#       "company_name": "XYZ Corp",
#       "n_years": 4,
#       "project_name": "Unknown",
#       "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.",
#       "tech_stack": "Unknown"
#     }
#   ],
#   "education": [
#     {
#       "university_name": "Unknown",
#       "degree": "Bachelor of Engineering in Information Technology",
#       "gpa": null
#     },
#     {
#       "university_name": "Unknown",
#       "degree": "Master of Business Administration",
#       "gpa": null
#     },
#     {
#       "university_name": "Unknown",
#       "degree": "Bachelor of Science in Computer Science",
#       "gpa": null
#     }
#   ],
#   "languages": null,
#   "skills": "Python & Machine Learning",
#   "address": null,
#   "linkedin": null
# }

# %%
# !pip install sentence-transformers scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\ganesh\anaconda3\lib\site-packages (5.0.0)
# Requirement already satisfied: scikit-learn in c:\users\ganesh\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: scipy in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (1.9.1)
# Requirement already satisfied: tqdm in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: Pillow in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (9.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (4.53.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (0.33.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\ganesh\anaconda3\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ganesh\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ganesh\anaconda3\lib\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ganesh\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: requests in c:\users\ganesh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\ganesh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ganesh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ganesh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: filelock in c:\users\ganesh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: networkx in c:\users\ganesh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\ganesh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ganesh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ganesh\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: colorama in c:\users\ganesh\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ganesh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\ganesh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ganesh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ganesh\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ganesh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganesh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganesh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ganesh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (1.26.11)

# %%
pip install --force-reinstall sentence-transformers
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.0.0-py3-none-any.whl (470 kB)
# Collecting torch>=1.11.0
#   Using cached torch-2.7.1-cp39-cp39-win_amd64.whl (216.0 MB)
# Collecting huggingface-hub>=0.20.0
#   Using cached huggingface_hub-0.33.2-py3-none-any.whl (515 kB)
# Collecting scipy
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting Pillow
#   Using cached pillow-11.3.0-cp39-cp39-win_amd64.whl (7.0 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# Collecting transformers<5.0.0,>=4.41.0
#   Using cached transformers-4.53.1-py3-none-any.whl (10.8 MB)
# Collecting typing_extensions>=4.5.0
#   Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Collecting filelock
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Collecting packaging>=20.9
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Collecting requests
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting numpy>=1.17
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Collecting regex!=2019.12.17
#   Using cached regex-2024.11.6-cp39-cp39-win_amd64.whl (274 kB)
# Collecting tokenizers<0.22,>=0.21
#   Using cached tokenizers-0.21.2-cp39-abi3-win_amd64.whl (2.5 MB)
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp39-cp39-win_amd64.whl (15 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.2-cp39-cp39-win_amd64.whl (105 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Installing collected packages: mpmath, urllib3, typing_extensions, threadpoolctl, sympy, safetensors, regex, pyyaml, Pillow, packaging, numpy, networkx, MarkupSafe, joblib, idna, fsspec, filelock, colorama, charset_normalizer, certifi, tqdm, scipy, requests, jinja2, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.14.1
#     Uninstalling typing_extensions-4.14.1:
#       Successfully uninstalled typing_extensions-4.14.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.5.3
#     Uninstalling safetensors-0.5.3:
#       Successfully uninstalled safetensors-0.5.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Ganesh\\anaconda3\\Lib\\site-packages\\~.mpy.libs\\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\ganesh\anaconda3\lib\site-packages)

# %%
import os
import json
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_community.document_loaders import PyPDFLoader
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ---- SETUP ----
os.environ["GROQ_API_KEY"] = "your api secret key"

# ---- SCHEMA ----
class Education(BaseModel):
    university_name: Optional[str] = None
    degree: Optional[str] = None
    gpa: Optional[float] = Field(None, ge=0, le=10.0)

class Experience(BaseModel):
    company_name: Optional[str]
    n_years: Optional[int]
    project_name: Optional[str]
    project_description: Optional[str]
    tech_stack: Optional[str]

class Resume(BaseModel):
    name: str
    age: Optional[int]
    email: str
    phone_number: str
    experience: Optional[List[Experience]]
    education: Optional[List[Education]]
    languages: Optional[str]
    skills: Optional[str]
    address: Optional[str]
    linkedin: Optional[str]

# ---- LLM SETUP ----
llm = ChatGroq(model_name="llama3-70b-8192", temperature=0)
parser = PydanticOutputParser(pydantic_object=Resume)

prompt = PromptTemplate(
    template="""
You are an AI assistant that extracts structured data from resumes.

Only return fields based on the schema:
{format_instructions}

⚠️ Ensure all important fields like university name and degree are not null. If not available, return "Unknown".

Respond ONLY with a valid JSON object without explanation, markdown, or commentary.

Resume Text:
{resume_text}
""",
    input_variables=["resume_text"],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# ---- LOAD RESUME ----
pdf_path = r"C:\Users\Ganesh\Downloads\Dataset_Extracted\Dataset\[Usecase 5] AI-Powered Job Application Screening System​\CVs1\C1161.pdf"
loader = PyPDFLoader(pdf_path)
docs = loader.load()
resume_text = "\n".join([doc.page_content for doc in docs])

# ---- GET RESPONSE ----
formatted_prompt = prompt.format_prompt(resume_text=resume_text)
response = llm.invoke(formatted_prompt.to_string())
response_text = response.content if hasattr(response, 'content') else str(response)

# ---- CLEAN JSON FROM RESPONSE ----
def extract_json_from_response(text: str) -> str:
    if "```" in text:
        parts = text.split("```")
        for part in parts:
            try:
                return json.loads(part.strip())
            except json.JSONDecodeError:
                continue
        raise ValueError("No valid JSON block found in code fences.")
    else:
        return json.loads(text.strip())

try:
    raw_json = extract_json_from_response(response_text)
except Exception as e:
    print("❌ Could not parse JSON from LLM response.\n", response_text)
    raise e

parsed_resume = Resume(**raw_json)

# ---- PRINT STRUCTURED RESUME ----
print("📄 Structured Resume:")
print(parsed_resume.model_dump_json(indent=2))

# ============================
# ✅ JOB MATCHING USING EMBEDDINGS
# ============================
# 1. Define Job Description
job_description = """
We are hiring a Python developer experienced in backend systems, data processing, and machine learning.
Preferred experience with Flask, REST APIs, and working with PostgreSQL or MongoDB.
"""

# 2. Prepare Resume Summary Text (combine fields)
resume_summary = resume_text  # Or use extracted fields like skills + experience

# 3. Load Embedding Model
embedder = SentenceTransformer('all-MiniLM-L6-v2')  # lightweight and effective

# 4. Compute Embeddings
resume_emb = embedder.encode([resume_summary])
job_emb = embedder.encode([job_description])

# 5. Compute Similarity
similarity_score = cosine_similarity(resume_emb, job_emb)[0][0]

# 6.Print Results
print("\n📊 Job Match Similarity Score:", round(similarity_score, 3))
if similarity_score > 0.8:
    print("✅ Excellent Match")
elif similarity_score > 0.6:
    print("👍 Good Match")
else:
    print("⚠️ Weak Match - Consider different job or resume updates.")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\Ganesh\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Ganesh\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ganesh\AppData\Local\Temp\ipykernel_12952\3013029139.py", line 9, in <module>
#     from sentence_transformers import SentenceTransformer
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\__init__.py", line 10, in <module>
#     from sentence_transformers.backend import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\backend.py", line 11, in <module>
#     from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\util.py", line 23, in <module>
#     from sklearn.metrics import pairwise_distances
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 20, in <module>
#     import pandas as pd
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 53, in <module>
#     from pandas.core import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Ganesh\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\Ganesh\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Ganesh\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Ganesh\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Ganesh\AppData\Local\Temp\ipykernel_12952\3013029139.py", line 9, in <module>
#     from sentence_transformers import SentenceTransformer
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\__init__.py", line 10, in <module>
#     from sentence_transformers.backend import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\backend.py", line 11, in <module>
#     from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sentence_transformers\util.py", line 23, in <module>
#     from sklearn.metrics import pairwise_distances
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\_array_api.py", line 17, in <module>
#     from .fixes import parse_version
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 20, in <module>
#     import pandas as pd
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 67, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\arrays\masked.py", line 61, in <module>
#     from pandas.core import (
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Ganesh\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Ganesh\anaconda3\lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# 📄 Structured Resume:
# {
#   "name": "Richard Molina",
#   "age": null,
#   "email": "richardmolina72@gmail.com",
#   "phone_number": "+1-908-7110",
#   "experience": [
#     {
#       "company_name": "DEF Ltd.",
#       "n_years": 4,
#       "project_name": "Unknown",
#       "project_description": "Led cross-functional teams to develop innovative solutions, increasing product adoption by 40%.",
#       "tech_stack": "Unknown"
#     },
#     {
#       "company_name": "XYZ Corp",
#       "n_years": 4,
#       "project_name": "Unknown",
#       "project_description": "Developed scalable backend applications, improved system efficiency by 30%, and led agile development sprints.",
#       "tech_stack": "Unknown"
#     }
#   ],
#   "education": [
#     {
#       "university_name": "Unknown",
#       "degree": "Bachelor of Engineering in Information Technology",
#       "gpa": null
#     },
#     {
#       "university_name": "Unknown",
#       "degree": "Master of Business Administration",
#       "gpa": null
#     },
#     {
#       "university_name": "Unknown",
#       "degree": "Bachelor of Science in Computer Science",
#       "gpa": null
#     }
#   ],
#   "languages": null,
#   "skills": "Python & Machine Learning",
#   "address": null,
#   "linkedin": null
# }
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Ganesh\anaconda3\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ganesh\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 📊 Job Match Similarity Score: 0.437
# ⚠️ Weak Match - Consider different job or resume updates.
